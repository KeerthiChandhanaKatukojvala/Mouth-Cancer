# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
file_path = r"C:\Users\HP\Downloads\ameya keerthi.xlsx"
df = pd.read_excel(file_path, sheet_name="Sheet1")


plt.figure(figsize=(6, 4))
sns.heatmap(df[['W1', 'size cm^3', 'W2','w1-w2','sgpt  1','sgpt 2']].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation heatmap")
plt.show()
